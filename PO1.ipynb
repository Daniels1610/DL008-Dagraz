# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as ds
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
ds = ds.fetch_california_housing()

ds_features = pd.DataFrame(ds.data, columns=ds.feature_names)
ds_target = pd.DataFrame(ds.target, columns=ds.target_names)
ds_features.insert(0, 'Intercept', 1)

X_train, X_test = train_test_split(ds_features, test_size=0.2, shuffle=False)
y_train, y_test = train_test_split(ds_target, test_size=0.2, shuffle=False)

tX_train, ty_train = tf.convert_to_tensor(X_train, dtype=tf.float64), tf.convert_to_tensor(y_train, dtype=tf.float64) 
tX_test, ty_test = tf.convert_to_tensor(X_test, dtype=tf.float64), tf.convert_to_tensor(y_test, dtype=tf.float64) 

ds_features
# Out:
# 2024-02-28 16:13:21.556780: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2024-02-28 16:13:21.556822: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2024-02-28 16:13:21.556838: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2024-02-28 16:13:21.556918: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-28 16:13:21.556987: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
#        Intercept  MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# 0              1  8.3252      41.0  6.984127   1.023810       322.0  2.555556
# ...

# %%
def ols(tp, xf):
    return tp[0] + tf.add_n([tf.multiply(tp[i],xf[i]) for i in range(1, len(tp))])

def mse(y_true, y_pred):
    return tf.reduce_mean(tf.square(y_true - y_pred))

# %%
X_transpose = tf.transpose(tX_train)
theta = tf.matmul(tf.linalg.inv(tf.matmul(X_transpose, tX_train)), tf.matmul(X_transpose, ty_train))
theta
# Out:
# <tf.Tensor: shape=(9, 1), dtype=float64, numpy=
# array([[-3.63905103e+01],
#        [ 4.47847084e-01],
#        [ 9.40820722e-03],
#        [-1.20960919e-01],
#        [ 7.10267788e-01],
#        [-1.47053238e-06],
#        [-8.81496820e-03],
#        [-4.21714509e-01],
#        [-4.29775301e-01]])>
